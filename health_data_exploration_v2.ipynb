# %%
import matplotlib.pyplot as plt
# %matplotlib inline 

import pandas as pd
import numpy as np
pd.set_option('display.mpl_style', 'default')

import csv

# %% [markdown]
# #### Beneficiary Summary - 3 Files

# %%
ben_2008 = pd.read_csv("DE1_0_2008_Beneficiary_Summary_File_Sample_1.csv", sep = ",")

# %%
ben_2009 = pd.read_csv("DE1_0_2009_Beneficiary_Summary_File_Sample_1.csv", sep = ",")

# %%
ben_2010 = pd.read_csv("DE1_0_2010_Beneficiary_Summary_File_Sample_1.csv", sep = ",")

# %%
df_ben = pd.concat([ben_2008, ben_2009])

# %%
df_ben = pd.concat([df_ben, ben_2010])

# %%
df_ben[df_ben['DESYNPUF_ID'] == '00013D2EFD8E45D1']
# Out:
#         DESYNPUF_ID  BENE_BIRTH_DT  BENE_DEATH_DT  BENE_SEX_IDENT_CD  \
# 0  00013D2EFD8E45D1       19230501            NaN                  1
# 0  00013D2EFD8E45D1       19230501            NaN                  1
# 0  00013D2EFD8E45D1       19230501            NaN                  1
#
#    BENE_RACE_CD BENE_ESRD_IND  SP_STATE_CODE  BENE_COUNTY_CD  \
# 0             1             0             26             950
# 0             1             0             26             950
# 0             1             0             26             950
#
#    BENE_HI_CVRAGE_TOT_MONS  BENE_SMI_CVRAGE_TOT_MONS  \
# 0                       12                        12
# 0                       12                        12
# 0                       12                        12
#
#    BENE_HMO_CVRAGE_TOT_MONS  PLAN_CVRG_MOS_NUM  SP_ALZHDMTA  SP_CHF  \
# 0                        12                 12            2       2
# 0                        12                 12            2       2
# 0                        12                 12            2       1
#
#    SP_CHRNKIDN  SP_CNCR  SP_COPD  SP_DEPRESSN  SP_DIABETES  SP_ISCHMCHT
# 0            2        2        2            2            2            2 ...
# 0            2        2        2            2            2            2 ...
# 0            2        2        2            2            2            2 ...
#
# [3 rows x 32 columns]

# %%
# Out:
# DE1_0_2008_Beneficiary_Summary_File_Sample_1.csv
# DE1_0_2008_to_2010_Carrier_Claims_Sample_1A.csv
# DE1_0_2008_to_2010_Carrier_Claims_Sample_1B.csv
# DE1_0_2008_to_2010_Inpatient_Claims_Sample_1.csv
# DE1_0_2008_to_2010_Outpatient_Claims_Sample_1.csv
# DE1_0_2008_to_2010_Prescription_Drug_Events_Sample_1.csv
# DE1_0_2009_Beneficiary_Summary_File_Sample_1.csv
# DE1_0_2010_Beneficiary_Summary_File_Sample_1.csv
# README.md
# health_data_exploration.ipynb
# parole.csv
# svg.html
# svg1.html
# zip_files/

# %% [markdown]
# #### Inpatient

# %%
inp_claims = pd.read_csv("DE1_0_2008_to_2010_Inpatient_Claims_Sample_1.csv", sep = ",")

# %%
inp_claims[inp_claims['DESYNPUF_ID']== '00013D2EFD8E45D1']
#inp_claims[df_ben['DESYNPUF_ID'] == '00013D2EFD8E45D1']
# Out:
#         DESYNPUF_ID           CLM_ID  SEGMENT  CLM_FROM_DT  CLM_THRU_DT  \
# 0  00013D2EFD8E45D1  196661176988405        1     20100312     20100313
#
#   PRVDR_NUM  CLM_PMT_AMT  NCH_PRMRY_PYR_CLM_PD_AMT  AT_PHYSN_NPI  \
# 0    2600GD         4000                         0    3139083564
#
#    OP_PHYSN_NPI  OT_PHYSN_NPI  CLM_ADMSN_DT ADMTNG_ICD9_DGNS_CD  \
# 0           NaN           NaN      20100312                4580
#
#    CLM_PASS_THRU_PER_DIEM_AMT  NCH_BENE_IP_DDCTBL_AMT  \
# 0                           0                    1100
#
#    NCH_BENE_PTA_COINSRNC_LBLTY_AM  NCH_BENE_BLOOD_DDCTBL_LBLTY_AM  \
# 0                               0                               0
#
#    CLM_UTLZTN_DAY_CNT  NCH_BENE_DSCHRG_DT CLM_DRG_CD
# 0                   1            20100313        217 ...
#
# [1 rows x 81 columns]

# %% [markdown]
# #### outpatient

# %%
out_claims = pd.read_csv("DE1_0_2008_to_2010_Outpatient_Claims_Sample_1.csv", sep = ",")
# Out:
# /Library/Python/2.7/site-packages/pandas/io/parsers.py:1070: DtypeWarning: Columns (21,23,24,25,26,27) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = self._reader.read(nrows)

# %%
out_claims[out_claims['DESYNPUF_ID']== '00013D2EFD8E45D1']
# Out:
#         DESYNPUF_ID           CLM_ID  SEGMENT  CLM_FROM_DT  CLM_THRU_DT  \
# 0  00013D2EFD8E45D1  542192281063886        1     20080904     20080904
#
#   PRVDR_NUM  CLM_PMT_AMT  NCH_PRMRY_PYR_CLM_PD_AMT  AT_PHYSN_NPI  \
# 0    2600RA           50                         0    4824842417
#
#    OP_PHYSN_NPI  OT_PHYSN_NPI  NCH_BENE_BLOOD_DDCTBL_LBLTY_AM ICD9_DGNS_CD_1  \
# 0           NaN           NaN                               0          V5841
#
#   ICD9_DGNS_CD_2 ICD9_DGNS_CD_3 ICD9_DGNS_CD_4 ICD9_DGNS_CD_5 ICD9_DGNS_CD_6  \
# 0            NaN            NaN            NaN            NaN            NaN
#
#   ICD9_DGNS_CD_7 ICD9_DGNS_CD_8
# 0            NaN            NaN ...
#
# [1 rows x 76 columns]

# %% [markdown]
# #### Prescription Drug Events

# %%
pres = pd.read_csv("DE1_0_2008_to_2010_Prescription_Drug_Events_Sample_1.csv", sep = ",")
# Out:
# /Library/Python/2.7/site-packages/pandas/io/parsers.py:1070: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = self._reader.read(nrows)

# %%
pres[pres['DESYNPUF_ID'] == '00013D2EFD8E45D1']
# Out:
#          DESYNPUF_ID           PDE_ID   SRVC_DT PROD_SRVC_ID  QTY_DSPNSD_NUM  \
# 0   00013D2EFD8E45D1  233664490397622  20080103    247037252              30
# 1   00013D2EFD8E45D1  233644490171972  20080105    223039502              10
# 2   00013D2EFD8E45D1  233974489116848  20080109    364724812             120
# 3   00013D2EFD8E45D1  233574491083209  20080123    179180672              30
# 4   00013D2EFD8E45D1  233024491180571  20080124  58016005300              30
# 5   00013D2EFD8E45D1  233884492803278  20080124  53650001801              30
# 6   00013D2EFD8E45D1  233594491623171  20080125      8032506             180
# 7   00013D2EFD8E45D1  233894491962732  20080129  58016081825             100
# 8   00013D2EFD8E45D1  233344491666810  20080201  51129143701              30
# 9   00013D2EFD8E45D1  233884490733605  20080205  67668013231              10
# 10  00013D2EFD8E45D1  233254492355736  20080214    254511335              60
# 11  00013D2EFD8E45D1  233784494196079  20080216  50070000265             360
# 12  00013D2EFD8E45D1  233604491119946  20080223  53014072671              30
# 13  00013D2EFD8E45D1  233404493740714  20080303  58016094835              30
#     DAYS_SUPLY_NUM  PTNT_PAY_AMT  TOT_RX_CST_AMT
# 0               20            10             120
# 1               10             0               0
# 2               30            10             110
# 3               30             0             240
# 4               30            70              70
# 5               30            10              40
# 6               30             0              10
# 7               30            20              10
# 8               30            10               0
# 9               10            10              30
# 10              30             0              10
# 11              30             0              10
# 12              30             0             150
# 13              30             0              40
# 14              30            10             230
# 15              30             0              20
# 16              30             0             120
# 17              30            20              20
# 18              30             0              10
# 19              30             0              10
# 20              10             0               0
# 21              30             0             220
# 22              30            10              20
# 23              30            10             120
# 24              90            10             100
# 25              30             0              60
# 26              30             0              30
# 27              30             0              50
# 28              30             0              10
# 29              30             0             160
# 30              30            10             170
# 31              30            10             180
# 32              30             0              10
# 33              30             0             150
# 34              30            80             570
# 35              30           170             180
# 36              30             0               0
# 37              20             0              90
# 38              30            10              10
# 39              30            10              20
# 40              30            30             120
# 41              30             0              50
# 42              30            70              70
# 43              30            10              10
# 44              30             0              20
# 45              30             0             410
# 46              30             0               0
# 47              10             0              20
# 48               0             0              10
# 49              90             0               0
# 50              70             0              10
# 51              30            10             150
# 52              30            20              30
# 53              30            10              80
# 54              30             0             480
# 55              30             0              30
# 56              30            10              10
# 57              30             0               0
# 58              30             0             150
# 59              10             0              30
#                ...           ...             ...
#
# [188 rows x 8 columns]

# %% [markdown]
# #### Claims Data

# %%
claims_df1 = pd.read_csv("DE1_0_2008_to_2010_Carrier_Claims_Sample_1A.csv", sep = ",")
# Out:
# /Library/Python/2.7/site-packages/pandas/io/parsers.py:1070: DtypeWarning: Columns (9,10,11,46,47,48,49,50,135,136,137,138,139,140,141) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = self._reader.read(nrows)

# %%
claims_df1.head()

claims_df1[claims_df1['DESYNPUF_ID'] == '00013D2EFD8E45D1']
# Out:
#         DESYNPUF_ID           CLM_ID  CLM_FROM_DT  CLM_THRU_DT ICD9_DGNS_CD_1  \
# 0  00013D2EFD8E45D1  887733386680966     20090725     20090725           7245
# 1  00013D2EFD8E45D1  887213386947664     20091014     20091014           3598
# 2  00013D2EFD8E45D1  887243388666441     20100401     20100401          29606
# 3  00013D2EFD8E45D1  887893388307089     20100817     20100817           8410
# 4  00013D2EFD8E45D1  887463387476539     20101105     20101105          29521
#
#   ICD9_DGNS_CD_2 ICD9_DGNS_CD_3 ICD9_DGNS_CD_4 ICD9_DGNS_CD_5 ICD9_DGNS_CD_6  \
# 0           7244           6272            NaN            NaN            NaN
# 1          27541            NaN            NaN            NaN            NaN
# 2            NaN            NaN            NaN            NaN            NaN
# 3           8472           8409            NaN            NaN            NaN
# 4            NaN            NaN            NaN            NaN            NaN
#
#   ICD9_DGNS_CD_7 ICD9_DGNS_CD_8  PRF_PHYSN_NPI_1  PRF_PHYSN_NPI_2  \
# 0            NaN            NaN       7128674558              NaN
# 1            NaN            NaN       9382129590              NaN
# 2            NaN            NaN       2657039888              NaN
# 3            NaN            NaN       1112729228              NaN
# 4            NaN            NaN       3517371403              NaN
#
#    PRF_PHYSN_NPI_3  PRF_PHYSN_NPI_4  PRF_PHYSN_NPI_5  PRF_PHYSN_NPI_6  \
# 0              NaN              NaN              NaN              NaN
# 1              NaN              NaN              NaN              NaN
# 2              NaN              NaN              NaN              NaN
# 3              NaN              NaN              NaN              NaN
# 4              NaN              NaN              NaN              NaN
#
#    PRF_PHYSN_NPI_7  PRF_PHYSN_NPI_8
# 0              NaN              NaN ...
# 1              NaN              NaN ...
# 2              NaN              NaN ...
# 3              NaN              NaN ...
# 4              NaN              NaN ...
#
# [5 rows x 142 columns]
